# %%
# far corner

import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15,15)
fig, ax = plt.subplots()

def drawWall(ax, label, line):
    ax.plot([i for i in range(len(line))],line, label=label)

drawWall(ax, "at wall", [219.80555555555554, 210.50378787878788, 200.4672619047619, 195.82575757575756, 193.546875, 195.20833333333334, 199.44791666666666, 208.67083333333332, 218.3452380952381, 237.61607142857142])
drawWall(ax, "at wall 45",  [274.9375, 292.51785714285717, 313.6363636363636, 338.4672619047619, 375.8974358974359, 422.09722222222223, 483.9479166666667, 585.3690476190476, 735.4345238095239, 845.2135416666666])
drawWall(ax, "at wall 60",  [401.75, 431.07738095238096, 485.8392857142857, 528.5530303030303, 617.3977272727273, 810.5178571428571, 1211.9318181818182, 1519.9444444444443, 1545.9490740740741, 1549.090909090909])
drawWall(ax, "at wall almost parallel", [519.8657407407408, 578.5666666666667, 701.2916666666666, 941.9739583333334, 1349.2767857142858, 1538.592261904762, 1531.9166666666667, 1527.3101851851852, 1548.9970238095239, 1573.092261904762])
drawWall(ax, "at wall almost parallel even close", [765.7708333333334, 1010.0625, 1370.220238095238, 1557.359375, 1542.5265151515152, 1540.547619047619, 1556.9722222222222, 1584.1636904761904, 1340.875, 792.7410714285714])
drawWall(ax, "at wall parallel", [1055.875, 1407.9618055555557, 1566.1958333333334, 1556.0416666666667, 1548.3854166666667, 1568.2261904761904, 1594.3363095238096, 1317.2948717948718, 812.8125, 597.810606060606])

ax.grid(True)
ax.legend()
#ax.set_ylim(150,700)
#ax.set_xlim(0,80)
    
plt.show()

# %%
# closest corner

import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15,15)
fig, ax = plt.subplots()

def drawWall(ax, label, line):
    ax.plot([i for i in range(len(line))],line, label=label)

drawWall(ax, "at wall", [253.6845238095238, 240.48611111111111, 232.59469696969697, 224.11904761904762, 224.04166666666666, 226.25520833333334, 233.23958333333334, 242.57142857142858, 256.78125, 286.675])
drawWall(ax, "at wall 30", [219.73958333333334, 223.12152777777777, 228.57738095238096, 237.0625, 253.1060606060606, 273.9010416666667, 299.7886904761905, 333.5833333333333, 379.1547619047619, 426.78125])
drawWall(ax, "at wall 37", [268.6166666666667, 276.35714285714283, 288.05833333333334, 309.6904761904762, 344.265625, 376.1488095238095, 444.6607142857143, 440.8958333333333, 437.1302083333333, 431.0885416666667])
drawWall(ax, "at wall 40", [285.4940476190476, 297.8044871794872, 318.83680555555554, 346.5059523809524, 385.8065476190476, 415.4423076923077, 433.44642857142856, 417.90416666666664, 397.1770833333333, 397.1197916666667])
drawWall(ax, "at wall 45", [355.2125, 376.5416666666667, 395.30357142857144, 412.6302083333333, 413.87916666666666, 382.375, 358.3645833333333, 341.0677083333333, 328.90625, 335.71875])
drawWall(ax, "at wall 60", [436.1934523809524, 401.2951388888889, 371.0151515151515, 346.53125, 326.578125, 310.1145833333333, 296.162037037037, 285.9895833333333, 281.82575757575756, 306.0989583333333])
drawWall(ax, "at wall parallel", [310.57916666666665, 296.1875, 287.4625, 281.76666666666665, 279.88392857142856, 283.8541666666667, 292.0833333333333, 302.9322916666667, 317.1979166666667, 347.0625])

ax.grid(True)
ax.legend()
#ax.set_ylim(150,700)
#ax.set_xlim(0,80)
    
plt.show()
