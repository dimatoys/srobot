plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
plt.rcParams["figure.figsize"] = (15,15)
fig, ax = plt.subplots()

def drawWall(ax, file):
    ax.plot([i for i in range(len(data4[file]))],data4[file], label=file)

drawWall(ax, "depth_wall40")
drawWall(ax, "depth_wall40_30")
drawWall(ax, "depth_wall40_45")
drawWall(ax, "depth_wall40_60")
    
ax.grid(True)
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_major_locator(MultipleLocator(10))
ax.legend()
#ax.set_ylim(150,700)
#ax.set_xlim(0,80)
    
plt.show()

# %%
data = {"gate_40_20": [430.2827380952381, 424.24242424242425, 433.3541666666667, 585.4970238095239, 611.4613095238095, 675.0684523809524, 561.96875, 417.8154761904762, 431.36309523809524, 456.2708333333333],
"gate_40_30": [446.03125, 618.8720238095239, 558.2884615384615, 608.5705128205128, 602.7731481481482, 785.9125, 714.5565476190476, 629.7820512820513, 442.6510416666667, 455.7083333333333],
"gate_40_40": [623.5446428571429, 632.9702380952381, 674.9583333333334, 616.0178571428571, 709.719696969697, 817.4583333333334, 796.5885416666666, 779.2307692307693, 686.6666666666666, 479.6145833333333],
"wall50_turn_30":[603.8833333333333, 636.1071428571429, 749.7314814814815, 667.75, 673.2731481481482, 538.3333333333334, 526.9880952380952, 516.9833333333333, 512.5505952380952, 518.1875],
"corner_50_45": [586.8518518518518, 672.7013888888889, 722.5595238095239, 682.3571428571429, 454.5925925925926, 433.9732142857143, 415.8541666666667, 406.51488095238096, 402.8525641025641, 417.19642857142856],
"incorner70": [726.9431818181819, 697.5952380952381, 682.4642857142857, 668.2113095238095, 665.9131944444445, 664.9553571428571, 663.2692307692307, 686.5416666666666, 677.3782051282051, 668.6011904761905],
"incorner50":[512.4431818181819, 519.4077380952381, 500.05059523809524, 495.8392857142857, 502.48511904761904, 494.7202380952381, 494.42261904761904, 516.047619047619, 515.2380952380952, 528.4345238095239],
"incorner50_turn30":[373.7083333333333, 403.1666666666667, 436.828125, 485.64166666666665, 543.0787037037037, 545.4196428571429, 541.4458333333333, 526.8564814814815, 516.1625, 514.0416666666666]}

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15,15)
fig, ax = plt.subplots()

def drawWall(ax, file):
    ax.plot([i for i in range(len(data[file]))],data[file], label=file)

drawWall(ax, "gate_40_20")
drawWall(ax, "gate_40_30")
drawWall(ax, "gate_40_40")


ax.grid(True)
ax.legend()
#ax.set_ylim(150,700)
#ax.set_xlim(0,80)
    
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15,15)
fig, ax = plt.subplots()

def drawWall(ax, file):
    ax.plot([i for i in range(len(data[file]))],data[file], label=file)

drawWall(ax, "corner_50_45")

ax.grid(True)
ax.legend()
#ax.set_ylim(150,700)
#ax.set_xlim(0,80)
    
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15,15)
fig, ax = plt.subplots()

def drawWall(ax, file):
    ax.plot([i for i in range(len(data[file]))],data[file], label=file)

drawWall(ax, "incorner50_turn30")

ax.grid(True)
ax.legend()
#ax.set_ylim(150,700)
#ax.set_xlim(0,80)
    
plt.show()
